# %%
from bfsk.bfsk import DEV
import matplotlib.pyplot as plt
from IPython.display import clear_output, display

# %%
d = DEV()

# %%
print(d)
# Out:
# <bfsk.bfsk.DEV object at 0x18FC9BB0>

# %%
#d.about()

# %%
d.open()

# %%
try:
    while 1:
        d.daq_bfsk(499)
        r = d.get_range(d.get_if0(), d.get_if1())
        clear_output(wait=True)
        print(f'{r:.3f}', end='', flush=True)
except KeyboardInterrupt:
    pass
# Out:
# 0.000
