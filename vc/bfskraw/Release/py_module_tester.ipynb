# %%
import bfsk.bfsk
from bfsk.bfsk import DEV
from bfsk.bfsk import support_mcu
import matplotlib.pyplot as plt
from IPython.display import clear_output, display

# %%
dir(bfsk.bfsk)
# Out:
# ['C',
#  'DEV',
#  'Enum',
#  'FREQ_OFFSET',
#  'READ_BUF_SIZE',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'apFFT',
#  'ctypes',
#  'fft',
#  'fftshift',
#  'getListMaxNumIndex',
#  'heapq',
#  'np',
#  'queue',
#  'support_mcu',
#  'unique']

# %%
dir(bfsk.bfsk.DEV)
# Out:
# ['_DEV__read_raw',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'about',
#  'daq_bfsk',
#  'get_if0',
#  'get_if1',
#  'get_range',
#  'open']

# %%
dir(bfsk.bfsk.support_mcu)
# Out:
# ['ACM32F403',
#  'HC32F460',
#  'N32G4FRKE',
#  'OTHERS',
#  'PT32Z192',
#  '__class__',
#  '__doc__',
#  '__members__',
#  '__module__']

# %%
d = DEV(support_mcu.HC32F460)
print(d)
# Out:
# 0
# 0x20002240
# <bfsk.bfsk.DEV object at 0x1A4972C8>

# %%
d = DEV(support_mcu.N32G4FRKE)
print(d)
# Out:
# 3
# 0x20002240
# <bfsk.bfsk.DEV object at 0x1A497520>

# %%
d.about()

# %%
d.open()

# %%
r_list = []
try:
    while 1:
        d.daq_bfsk(499)
        r = d.get_range(d.get_if0(), d.get_if1())
        r_list.append(r)
        clear_output(wait=True)
        print(f'{r:.3f}', end='', flush=True)
        plt.plot(r_list)
        plt.xlabel('x')
        plt.ylabel('y')
        plt.show()
        plt.pause(0.5)
except KeyboardInterrupt:
    pass
# Out:
# 0.475
