# %%
from bfsk.bfsk import DEV
import matplotlib.pyplot as plt
from IPython.display import clear_output, display

# %%
d = DEV()

# %%
print(d)
# Out:
# <bfsk.bfsk.DEV object at 0x192CA958>

# %%
#d.about()

# %%
d.open()

# %%
r_list = []
try:
    while 1:
        d.daq_bfsk(499)
        r = d.get_range(d.get_if0(), d.get_if1())
        r_list.append(r)
        clear_output(wait=True)
        print(f'{r:.3f}', end='', flush=True)
        plt.plot(r_list)
        plt.xlabel('x')
        plt.ylabel('y')
        plt.show()
        plt.pause(0.5)
except KeyboardInterrupt:
    pass
# Out:
# 20.765
