# %%
import time
import bfsk

# %%
time.time()
# Out:
# 1639802991.9641676

# %%
bfsk.apFFT
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6160/3331694273.py in <module>
# ----> 1 bfsk.apFFT
#
# AttributeError: module 'bfsk' has no attribute 'apFFT'
